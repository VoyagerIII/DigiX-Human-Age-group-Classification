# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
import lightgbm as lgb
import scipy
from scipy import sparse
from pandas.core.common import SettingWithCopyWarning
import scipy.stats as sp
import pandas as pd
import numpy as np
from collections import Counter
import warnings
import time
import sys
import random
import os
import gc
import datetime

import matplotlib.pyplot as plt

# %%
path = '../data/'
data_path = '../trainTestData/'
middle_path = '../model/'

train_y = pd.read_csv(path + 'age_train.csv', names=['uid', 'label'])
sub = pd.read_csv(path + 'age_test.csv', names=['uid'])

train_csr = sparse.load_npz(data_path + 'trainData30.npz')
test_csr = sparse.load_npz(data_path + 'testData30.npz')
train_y = train_y["label"].values

# train_csr = train_csr[:200]
# train_y = train_y['label'].values[:200]
# print(train_csr.shape, test_csr.shape)

# %%
lgb_model = lgb.LGBMClassifier(
    boosting_type='gbdt',
    objective='multiclass',
    metrics='multi_error',
    num_class=6,
    n_estimators=20000,
    learning_rate=0.1,
    num_leaves=512,
    max_depth=-1,
    subsample=0.95,
    colsample_bytree=0.5,
    subsample_freq=1,
    reg_alpha=1,
    reg_lambda=1,
    random_state=42,
    n_jobs=48,
    
        
    gpu_platform_id=-1,
    gpu_device_id=-1,
    device='gpu',
    max_bin=255,
)

oof = np.zeros((train_csr.shape[0], 6))
sub_preds = np.zeros((test_csr.shape[0], 6))
skf = StratifiedKFold(n_splits=5, random_state=812, shuffle=True)
t = time.time()


for index, (train_index, test_index) in enumerate(skf.split(train_csr, train_y)):
    print('Fold {}'.format(index + 1))
    lgb_model.fit(train_csr[train_index], train_y[train_index],
                  eval_set=[(train_csr[train_index], train_y[train_index]),
                            (train_csr[test_index], train_y[test_index])],
                  eval_names=['train', 'valid'],
                  early_stopping_rounds=200, verbose=10)

    oof[test_index] = lgb_model.predict_proba(train_csr[test_index], num_iteration=lgb_model.best_iteration_)
    sub_preds += lgb_model.predict_proba(test_csr, num_iteration=lgb_model.best_iteration_) / skf.n_splits
#     lgb_model.savetxt(middle_path+'model/lgb_zl'+str(index)+'_model.txt')
    joblib.dump(lgb_model, '../model/lgb_zl_13100_2'+str(index)+'_model.pkl')

print(oof.shape, train_y.shape)
# Out:
# Fold 1
# Training until validation scores don't improve for 200 rounds.
# [10]	train's multi_error: 0.599182	valid's multi_error: 0.60391
# [20]	train's multi_error: 0.568929	valid's multi_error: 0.577846
# [30]	train's multi_error: 0.556034	valid's multi_error: 0.568211
# [40]	train's multi_error: 0.54878	valid's multi_error: 0.564065
# [50]	train's multi_error: 0.54332	valid's multi_error: 0.561458
# [60]	train's multi_error: 0.538996	valid's multi_error: 0.559841
# [70]	train's multi_error: 0.535531	valid's multi_error: 0.558614
# [80]	train's multi_error: 0.532387	valid's multi_error: 0.557866
# [90]	train's multi_error: 0.529215	valid's multi_error: 0.557371
# [100]	train's multi_error: 0.526478	valid's multi_error: 0.557087
# [110]	train's multi_error: 0.523807	valid's multi_error: 0.556761
# [120]	train's multi_error: 0.521263	valid's multi_error: 0.556821
# [130]	train's multi_error: 0.518757	valid's multi_error: 0.556632
# [140]	train's multi_error: 0.516285	valid's multi_error: 0.556219
# [150]	train's multi_error: 0.514095	valid's multi_error: 0.556179
# [160]	train's multi_error: 0.511718	valid's multi_error: 0.555933
# [170]	train's multi_error: 0.50956	valid's multi_error: 0.555771
# [180]	train's multi_error: 0.507401	valid's multi_error: 0.555769
# [190]	train's multi_error: 0.505394	valid's multi_error: 0.555771
# [200]	train's multi_error: 0.503324	valid's multi_error: 0.555813
# [210]	train's multi_error: 0.501257	valid's multi_error: 0.555915
# [220]	train's multi_error: 0.499181	valid's multi_error: 0.555729
# [230]	train's multi_error: 0.497198	valid's multi_error: 0.555816
# [240]	train's multi_error: 0.49527	valid's multi_error: 0.555831
# [250]	train's multi_error: 0.493323	valid's multi_error: 0.555883
# [260]	train's multi_error: 0.491646	valid's multi_error: 0.555903
# [270]	train's multi_error: 0.489715	valid's multi_error: 0.55602
# [280]	train's multi_error: 0.487884	valid's multi_error: 0.555896
# [290]	train's multi_error: 0.486071	valid's multi_error: 0.555923
# [300]	train's multi_error: 0.484336	valid's multi_error: 0.555908
# [310]	train's multi_error: 0.48265	valid's multi_error: 0.555856
# [320]	train's multi_error: 0.480789	valid's multi_error: 0.55601
# [330]	train's multi_error: 0.479083	valid's multi_error: 0.555848
# [340]	train's multi_error: 0.477527	valid's multi_error: 0.556107
# [350]	train's multi_error: 0.475844	valid's multi_error: 0.556378
# [360]	train's multi_error: 0.474098	valid's multi_error: 0.556144
# [370]	train's multi_error: 0.472609	valid's multi_error: 0.556184
# [380]	train's multi_error: 0.471022	valid's multi_error: 0.556152
# [390]	train's multi_error: 0.469418	valid's multi_error: 0.556269
# [400]	train's multi_error: 0.46783	valid's multi_error: 0.556241
# Early stopping, best iteration is:
# [206]	train's multi_error: 0.502106	valid's multi_error: 0.555617
# Fold 2
# Training until validation scores don't improve for 200 rounds.
# [10]	train's multi_error: 0.59881	valid's multi_error: 0.604279
# [20]	train's multi_error: 0.568646	valid's multi_error: 0.578878
# [30]	train's multi_error: 0.555872	valid's multi_error: 0.569351
# [40]	train's multi_error: 0.548496	valid's multi_error: 0.564313
# [50]	train's multi_error: 0.543266	valid's multi_error: 0.561475
# [60]	train's multi_error: 0.538978	valid's multi_error: 0.559811
# [70]	train's multi_error: 0.535652	valid's multi_error: 0.558721
# [80]	train's multi_error: 0.532353	valid's multi_error: 0.558112
# [90]	train's multi_error: 0.529425	valid's multi_error: 0.557378
# [100]	train's multi_error: 0.526573	valid's multi_error: 0.556721
# [110]	train's multi_error: 0.52385	valid's multi_error: 0.556657
# [120]	train's multi_error: 0.521289	valid's multi_error: 0.556448
# [130]	train's multi_error: 0.518789	valid's multi_error: 0.556219
# [140]	train's multi_error: 0.516475	valid's multi_error: 0.556182
# [150]	train's multi_error: 0.514176	valid's multi_error: 0.555968
# [160]	train's multi_error: 0.511757	valid's multi_error: 0.555905
# [170]	train's multi_error: 0.509752	valid's multi_error: 0.555858
# [180]	train's multi_error: 0.507604	valid's multi_error: 0.555823
# [190]	train's multi_error: 0.505588	valid's multi_error: 0.555851
# [200]	train's multi_error: 0.503466	valid's multi_error: 0.555998
# [210]	train's multi_error: 0.501267	valid's multi_error: 0.555925
# [220]	train's multi_error: 0.499185	valid's multi_error: 0.555761
# [230]	train's multi_error: 0.497236	valid's multi_error: 0.555828
# [240]	train's multi_error: 0.495289	valid's multi_error: 0.555893
# [250]	train's multi_error: 0.493313	valid's multi_error: 0.555953
# [260]	train's multi_error: 0.491407	valid's multi_error: 0.555883
# [270]	train's multi_error: 0.489638	valid's multi_error: 0.555953
# [280]	train's multi_error: 0.487892	valid's multi_error: 0.556047
# [290]	train's multi_error: 0.486073	valid's multi_error: 0.556119
# [300]	train's multi_error: 0.484331	valid's multi_error: 0.556097
# [310]	train's multi_error: 0.482596	valid's multi_error: 0.556057
# [320]	train's multi_error: 0.480951	valid's multi_error: 0.556184
# [330]	train's multi_error: 0.479264	valid's multi_error: 0.556311
# [340]	train's multi_error: 0.477657	valid's multi_error: 0.556333
# [350]	train's multi_error: 0.476016	valid's multi_error: 0.556413
# [360]	train's multi_error: 0.47427	valid's multi_error: 0.556383
# [370]	train's multi_error: 0.472688	valid's multi_error: 0.556443
# [380]	train's multi_error: 0.471054	valid's multi_error: 0.556644
# [390]	train's multi_error: 0.469561	valid's multi_error: 0.556739
# [400]	train's multi_error: 0.467966	valid's multi_error: 0.556794
# [410]	train's multi_error: 0.466481	valid's multi_error: 0.556828
# Early stopping, best iteration is:
# [219]	train's multi_error: 0.499381	valid's multi_error: 0.555731
# Fold 3
# Training until validation scores don't improve for 200 rounds.
# [10]	train's multi_error: 0.600006	valid's multi_error: 0.605542
# [20]	train's multi_error: 0.568395	valid's multi_error: 0.577241
# [30]	train's multi_error: 0.555745	valid's multi_error: 0.56803
# [40]	train's multi_error: 0.548306	valid's multi_error: 0.563388
# [50]	train's multi_error: 0.543506	valid's multi_error: 0.560891
# [60]	train's multi_error: 0.539519	valid's multi_error: 0.559259
# [70]	train's multi_error: 0.536034	valid's multi_error: 0.558756
# [80]	train's multi_error: 0.533081	valid's multi_error: 0.557769
# [90]	train's multi_error: 0.530101	valid's multi_error: 0.556833
# [100]	train's multi_error: 0.52727	valid's multi_error: 0.556256
# [110]	train's multi_error: 0.524636	valid's multi_error: 0.555664
# [120]	train's multi_error: 0.522165	valid's multi_error: 0.55546
# [130]	train's multi_error: 0.519795	valid's multi_error: 0.555274
# [140]	train's multi_error: 0.517448	valid's multi_error: 0.555057
# [150]	train's multi_error: 0.515137	valid's multi_error: 0.554779
# [160]	train's multi_error: 0.513025	valid's multi_error: 0.554527
# [170]	train's multi_error: 0.510848	valid's multi_error: 0.554445
# [180]	train's multi_error: 0.5087	valid's multi_error: 0.554455
# [190]	train's multi_error: 0.506733	valid's multi_error: 0.5546
# [200]	train's multi_error: 0.504459	valid's multi_error: 0.554502
# [210]	train's multi_error: 0.502607	valid's multi_error: 0.554582
# [220]	train's multi_error: 0.500626	valid's multi_error: 0.554634
# [230]	train's multi_error: 0.49873	valid's multi_error: 0.554555
# [240]	train's multi_error: 0.496808	valid's multi_error: 0.55447
# [250]	train's multi_error: 0.494994	valid's multi_error: 0.554609
# [260]	train's multi_error: 0.493146	valid's multi_error: 0.554669
# [270]	train's multi_error: 0.491244	valid's multi_error: 0.554629
# [280]	train's multi_error: 0.489606	valid's multi_error: 0.554642
# [290]	train's multi_error: 0.487914	valid's multi_error: 0.554761
# [300]	train's multi_error: 0.486095	valid's multi_error: 0.55498
# [310]	train's multi_error: 0.484396	valid's multi_error: 0.555047
# [320]	train's multi_error: 0.482686	valid's multi_error: 0.555154
# [330]	train's multi_error: 0.481032	valid's multi_error: 0.555189
# [340]	train's multi_error: 0.479351	valid's multi_error: 0.555147
# [350]	train's multi_error: 0.477709	valid's multi_error: 0.55505
# [360]	train's multi_error: 0.476076	valid's multi_error: 0.555122
# [370]	train's multi_error: 0.474366	valid's multi_error: 0.555326
# Early stopping, best iteration is:
# [177]	train's multi_error: 0.509392	valid's multi_error: 0.554284
# Fold 4
# Training until validation scores don't improve for 200 rounds.
# [10]	train's multi_error: 0.599075	valid's multi_error: 0.604159
# [20]	train's multi_error: 0.568899	valid's multi_error: 0.577774
# [30]	train's multi_error: 0.556091	valid's multi_error: 0.568828
# [40]	train's multi_error: 0.548706	valid's multi_error: 0.563604
# [50]	train's multi_error: 0.543367	valid's multi_error: 0.560965
# [60]	train's multi_error: 0.539044	valid's multi_error: 0.559706
# [70]	train's multi_error: 0.535604	valid's multi_error: 0.558614
# [80]	train's multi_error: 0.532318	valid's multi_error: 0.557958
# [90]	train's multi_error: 0.529277	valid's multi_error: 0.557199
# [100]	train's multi_error: 0.526392	valid's multi_error: 0.556963
# [110]	train's multi_error: 0.523783	valid's multi_error: 0.5569
# [120]	train's multi_error: 0.521247	valid's multi_error: 0.556652
# [130]	train's multi_error: 0.518753	valid's multi_error: 0.556659
# [140]	train's multi_error: 0.516395	valid's multi_error: 0.556206
# [150]	train's multi_error: 0.51411	valid's multi_error: 0.555818
# [160]	train's multi_error: 0.511827	valid's multi_error: 0.555746
# [170]	train's multi_error: 0.509668	valid's multi_error: 0.555634
# [180]	train's multi_error: 0.507364	valid's multi_error: 0.555719
# [190]	train's multi_error: 0.505354	valid's multi_error: 0.55557
# [200]	train's multi_error: 0.50337	valid's multi_error: 0.55556
# [210]	train's multi_error: 0.501384	valid's multi_error: 0.555597
# [220]	train's multi_error: 0.499439	valid's multi_error: 0.555818
# [230]	train's multi_error: 0.497494	valid's multi_error: 0.555542
# [240]	train's multi_error: 0.495539	valid's multi_error: 0.555567
# [250]	train's multi_error: 0.493598	valid's multi_error: 0.555711
# [260]	train's multi_error: 0.491637	valid's multi_error: 0.555562
# [270]	train's multi_error: 0.489831	valid's multi_error: 0.555555
# [280]	train's multi_error: 0.487997	valid's multi_error: 0.555597
# [290]	train's multi_error: 0.486171	valid's multi_error: 0.555726
# [300]	train's multi_error: 0.484403	valid's multi_error: 0.555711
# [310]	train's multi_error: 0.482701	valid's multi_error: 0.55553
# [320]	train's multi_error: 0.480924	valid's multi_error: 0.555759
# [330]	train's multi_error: 0.479267	valid's multi_error: 0.555866
# [340]	train's multi_error: 0.47756	valid's multi_error: 0.555652
# [350]	train's multi_error: 0.475904	valid's multi_error: 0.555674
# [360]	train's multi_error: 0.474325	valid's multi_error: 0.555627
# [370]	train's multi_error: 0.472778	valid's multi_error: 0.55553
# [380]	train's multi_error: 0.471005	valid's multi_error: 0.555654
# [390]	train's multi_error: 0.469434	valid's multi_error: 0.555632
# Early stopping, best iteration is:
# [192]	train's multi_error: 0.504919	valid's multi_error: 0.5554
# Fold 5
# Training until validation scores don't improve for 200 rounds.
# [10]	train's multi_error: 0.598881	valid's multi_error: 0.605281
# [20]	train's multi_error: 0.568748	valid's multi_error: 0.579366
# [30]	train's multi_error: 0.555858	valid's multi_error: 0.569629
# [40]	train's multi_error: 0.54834	valid's multi_error: 0.565274
# [50]	train's multi_error: 0.543013	valid's multi_error: 0.562443
# [60]	train's multi_error: 0.538734	valid's multi_error: 0.560943
# [70]	train's multi_error: 0.535289	valid's multi_error: 0.559532
# [80]	train's multi_error: 0.532208	valid's multi_error: 0.558617
# [90]	train's multi_error: 0.529268	valid's multi_error: 0.558269
# [100]	train's multi_error: 0.526435	valid's multi_error: 0.557759
# [110]	train's multi_error: 0.523706	valid's multi_error: 0.557318
# [120]	train's multi_error: 0.521234	valid's multi_error: 0.55705
# [130]	train's multi_error: 0.518784	valid's multi_error: 0.556796
# [140]	train's multi_error: 0.516479	valid's multi_error: 0.556669
# [150]	train's multi_error: 0.514315	valid's multi_error: 0.556552
# [160]	train's multi_error: 0.511953	valid's multi_error: 0.556512
# [170]	train's multi_error: 0.509905	valid's multi_error: 0.556396
# [180]	train's multi_error: 0.507705	valid's multi_error: 0.556254
# [190]	train's multi_error: 0.505687	valid's multi_error: 0.556226
# [200]	train's multi_error: 0.50364	valid's multi_error: 0.556311
# [210]	train's multi_error: 0.501562	valid's multi_error: 0.556318
# [220]	train's multi_error: 0.499675	valid's multi_error: 0.556396
# [230]	train's multi_error: 0.497662	valid's multi_error: 0.556209
# [240]	train's multi_error: 0.495697	valid's multi_error: 0.556204
# [250]	train's multi_error: 0.49382	valid's multi_error: 0.556433
# [260]	train's multi_error: 0.49196	valid's multi_error: 0.556527
# [270]	train's multi_error: 0.490131	valid's multi_error: 0.556634
# [280]	train's multi_error: 0.48822	valid's multi_error: 0.556657
# [290]	train's multi_error: 0.486496	valid's multi_error: 0.55642
# [300]	train's multi_error: 0.48466	valid's multi_error: 0.556473
# [310]	train's multi_error: 0.482983	valid's multi_error: 0.556505
# [320]	train's multi_error: 0.481248	valid's multi_error: 0.556692
# [330]	train's multi_error: 0.479533	valid's multi_error: 0.556689
# [340]	train's multi_error: 0.477947	valid's multi_error: 0.556629
# [350]	train's multi_error: 0.476314	valid's multi_error: 0.556679
# [360]	train's multi_error: 0.4747	valid's multi_error: 0.556694
# [370]	train's multi_error: 0.473095	valid's multi_error: 0.556612
# [380]	train's multi_error: 0.471475	valid's multi_error: 0.556649
# [390]	train's multi_error: 0.469868	valid's multi_error: 0.556617
# [400]	train's multi_error: 0.468453	valid's multi_error: 0.556736
# [410]	train's multi_error: 0.466764	valid's multi_error: 0.55652
# [420]	train's multi_error: 0.465382	valid's multi_error: 0.556493
# [430]	train's multi_error: 0.463759	valid's multi_error: 0.556552
# Early stopping, best iteration is:
# [234]	train's multi_error: 0.496777	valid's multi_error: 0.556142
# (2010000, 6) (2010000,)

# %%
cv_final = accuracy_score(train_y, np.argmax(oof, axis=1)+1)
print('\ncv acc:', cv_final)

sub['label'] = np.argmax(sub_preds, axis=1) + 1
# sub.to_csv(middle_path + 'sub_{}.csv'.format(cv_final), index=False)


oof = np.zeros((train_csr.shape[0], 6))
sub_preds = np.zeros((test_csr.shape[0], 6))
skf = StratifiedKFold(n_splits=5, random_state=812, shuffle=True)
t = time.time()
# Out:
# cv acc: 0.44456517412935326

# %%
for index, (train_index, test_index) in enumerate(skf.split(train_csr, train_y)):
    print('Fold {}'.format(index + 1))
    lgb_model = joblib.load('../model/lgb_zl_13100_2'+str(index)+'_model.pkl')

    oof[test_index] = lgb_model.predict_proba(train_csr[test_index], num_iteration=lgb_model.best_iteration_)
    sub_preds += lgb_model.predict_proba(test_csr, num_iteration=lgb_model.best_iteration_) / skf.n_splits


cv_final = accuracy_score(train_y, np.argmax(oof, axis=1)+1)
print('\ncv acc:', cv_final)

np.savetxt('../processed/lgboost_val_13100.txt', oof, fmt='%s', delimiter=',', newline='\n')
np.savetxt('../processed/lgboost_test_13100.txt', sub_preds, fmt='%s', delimiter=',', newline='\n')

sub['label'] = np.argmax(sub_preds, axis=1) + 1
# sub.to_csv(middle_path + 'sub_{}.csv'.format(cv_final), index=False)
# Out:
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
#
# cv acc: 0.44456517412935326
